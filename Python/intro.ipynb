# %% [markdown]
# Task 1.1 Introduction

# %%
def calcMeans(dataframe):
    # Returns a NumPy ndarray instead of pandas Series
    means = dataframe.apply(lambda col: col.mean()).to_numpy()
    return means

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
iris_X, iris_y = datasets.load_iris(return_X_y=True, as_frame=True)
means = calcMeans(iris_X)
print("Calculated Means:\n", means)
print("\nValidation with describe():\n", iris_X.describe().loc['mean'])
# Out:
# Calculated Means:
#  sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64
#
# Validation with describe():
#  sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# Name: mean, dtype: float64

# %% [markdown]
# pip install scikit-learn
# pip install pandas scikit-learn
#
# Ausgeführt damit obiges funktioniert

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.bar(means.index, means.values)
plt.xlabel('Features')
plt.ylabel('Mean Value')
plt.title('Mean of Numeric Features in Iris Dataset')
plt.grid(True)
plt.show()
